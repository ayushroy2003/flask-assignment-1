# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?
#
# Ans -
# flask is lightweight and popular web framework for web application in python
#
# Advantage
#
# 1. lightweight and minimalistic
# 2.  flexiblity
# 3. easy to learn
# 4. widely used
# 5. restful routing

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %% [markdown]
# Ans-
# ![ayush.png](attachment:4809e959-edac-456e-8006-64dd222ebdee.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?
#
# Ans- In Flask app routing refers to the defineing URL routes of web application
# these routes are defined using the ' @app.route ' decorator in Flask
#
# We use app routes to define the different URLs that users can visit and the functions that should be called when they visit those URLs:
#
#
# app routing in Flask is a fundamental concept that enables you to define the structure and behavior of your web application. It allows you to map URLs to specific view functions, which handle incoming requests and generate responses, making it a crucial part of building web applications with Flask.

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
#
# Company Name: ABC Corporation
#
# Location: India
#
# Contact Detail: 999-999-9999

# %% [markdown]
# ![Screenshot (31).png](attachment:81896d21-9389-4b50-bdee-08813e7399f3.png)

# %% [markdown]
# ![Screenshot (32).jpg](attachment:ac183955-0d22-4d9c-8065-397e502218ca.jpg)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.

# %% [markdown]
# Ans - in flask 'url_for()' function is used for url buildings

# %%
from flask import Flask, url_for

app = Flask (__name__)

@app.route('/')
def home():
    return "This is the home page"

@app.route('/about')
def about():
    return "This is the about page"

with app.test_request_context():
    print(url_for('home'))
    print(url_for('about'))

if __name__ == '__main__':
    app.run(debug = True)
